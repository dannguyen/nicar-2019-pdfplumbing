# %%
from pdfplumber import pdfplumber

IN_PATH = 'gsk-grants-2017.pdf'

the_pdf = pdfplumber.open(IN_PATH)

# %%
# do class walkthrough here...

# %%
# cheatsheet for dan...
#
#
# one page
pg = the_pdf.pages[0]

px = pg.crop((0, 95, pg.width, pg.height))
px.to_image()

# %%
px.to_image().debug_tablefinder()
