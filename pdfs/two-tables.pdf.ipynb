# %%
from pdfplumber import pdfplumber
# https://www.hud.gov/topics/physical_inspection_scores/public_housing_property_physical_inspection_data
IN_PATH = 'camelot-two-tables-2.pdf'

the_pdf = pdfplumber.open(IN_PATH)
pg = the_pdf.pages[0]

# %%
pg.to_image(resolution=150).debug_tablefinder()

# %%
tblcfg = {
}
pg.to_image(resolution=150).debug_tablefinder(tblcfg)

# %%
tblcfg = {
}
pg.extract_tables(tblcfg)
# Out:
# [[['Table 6 : DISTRIBUTION (%) OF HOUSEHOLDS BY LITERACY STATUS OF'],
#   ['MALE HEAD OF THE HOUSEHOLD']],
#  [['Table 7 : DISTRIBUTION (%) OF HOUSEHOLDS BY LITERACY STATUS OF', None],
#   ['ADULT WOMEN', None],
#   [None, '']],
#  [[''], ['']],
#  [['', '', 'Literacy Status', None, None, None, None, None],
#   ['State', 'n', '', 'Read &', '', '', '', ''],
#   [None,
#    None,
#    'Illiterate',
#    None,
#    '1-4 std.',
#    '5-8 std.',
#    '9-12 std.',
#    'College'],
#   ['', '', None, 'Write', None, None, None, None],
#   [None, None, '', None, '', '', '', ''],
#   ['Kerala', '2400', '7.2', '0.5', '25.3', '20.1', '41.5', '5.5'],
#   ['Tamil Nadu', '2400', '21.4', '2.3', '8.8', '35.5', '25.8', '6.2'],
#   ['Karnataka', '2399', '37.4', '2.8', '12.5', '18.3', '23.1', '5.8'],
#   ['Andhra Pradesh', '2400', '54.0', '1.7', '8.4', '13.2', '18.8', '3.9'],
#   ['Maharashtra', '2400', '22.0', '0.9', '17.3', '20.3', '32.6', '7.0'],
# ...
